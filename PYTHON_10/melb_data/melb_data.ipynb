# %%
import numpy as np
import pandas as pd

# %%
melb_data = pd.read_csv('melb_data.csv', sep=',')

# %%
melb_data.head()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...  1.0     202.0         126.0     1970.0
# 1  4/02/2016       2.5  ...  0.0     156.0          79.0     1900.0
# 2  4/03/2017       2.5  ...  0.0     134.0         150.0     1900.0
# 3  4/03/2017       2.5  ...  1.0      94.0         126.0     1970.0
# 4  4/06/2016       2.5  ...  2.0     120.0         142.0     2014.0
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# ...

# %%
melb_data['Price'][15]
# Out:
# 1310000.0

# %%
melb_data['Date'][90]
# Out:
# '10/09/2016'

# %%
melb_data.loc[3521]["Landsize"] / melb_data.loc[1690]["Landsize"]
# Out:
# 2.7857142857142856

# %%
melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  float64
#  12  Bathroom       13580 non-null  float64
#  13  Car            13580 non-null  float64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  float64
# ...

# %%
melb_data['Car'] = melb_data['Car'].astype('int64')
melb_data['Bedroom'] = melb_data['Bedroom'].astype('int64')
melb_data['Bathroom'] = melb_data['Bathroom'].astype('int64')
melb_data['Propertycount'] = melb_data['Propertycount'].astype('int64')
melb_data['YearBuilt'] = melb_data['YearBuilt'].astype('int64')

# %%
melb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   index          13580 non-null  int64
#  1   Suburb         13580 non-null  object
#  2   Address        13580 non-null  object
#  3   Rooms          13580 non-null  int64
#  4   Type           13580 non-null  object
#  5   Price          13580 non-null  float64
#  6   Method         13580 non-null  object
#  7   SellerG        13580 non-null  object
#  8   Date           13580 non-null  object
#  9   Distance       13580 non-null  float64
#  10  Postcode       13580 non-null  int64
#  11  Bedroom        13580 non-null  int64
#  12  Bathroom       13580 non-null  int64
#  13  Car            13580 non-null  int64
#  14  Landsize       13580 non-null  float64
#  15  BuildingArea   13580 non-null  float64
#  16  YearBuilt      13580 non-null  int64
# ...

# %%
melb_data.describe()
# Out:
#               index         Rooms         Price      Distance      Postcode  \
# count  13580.000000  13580.000000  1.358000e+04  13580.000000  13580.000000
# mean    6789.500000      2.937997  1.075684e+06     10.137776   3105.301915
# std     3920.352663      0.955748  6.393107e+05      5.868725     90.676964
# min        0.000000      1.000000  8.500000e+04      0.000000   3000.000000
# 25%     3394.750000      2.000000  6.500000e+05      6.100000   3044.000000
# 50%     6789.500000      3.000000  9.030000e+05      9.200000   3084.000000
# 75%    10184.250000      3.000000  1.330000e+06     13.000000   3148.000000
# max    13579.000000     10.000000  9.000000e+06     48.100000   3977.000000
#
#             Bedroom      Bathroom           Car       Landsize  BuildingArea  \
# count  13580.000000  13580.000000  13580.000000   13580.000000  13580.000000
# mean       2.914728      1.534242      1.611856     558.416127    139.633972
# ...

# %%
melb_data.describe(include='all')
# Out:
#                index     Suburb           Address         Rooms   Type  \
# count   13580.000000      13580             13580  13580.000000  13580
# unique           NaN        314             13378           NaN      3
# top              NaN  Reservoir  36 Aberfeldie St           NaN      h
# freq             NaN        359                 3           NaN   9449
# mean     6789.500000        NaN               NaN      2.937997    NaN
# std      3920.352663        NaN               NaN      0.955748    NaN
# min         0.000000        NaN               NaN      1.000000    NaN
# 25%      3394.750000        NaN               NaN      2.000000    NaN
# 50%      6789.500000        NaN               NaN      3.000000    NaN
# 75%     10184.250000        NaN               NaN      3.000000    NaN
# max     13579.000000        NaN               NaN     10.000000    NaN
#
#                Price Method SellerG        Date      Distance  ...  \
# ...

# %%
melb_data['Suburb'].value_counts()
# Out:
# Reservoir         359
# Richmond          260
# Bentleigh East    249
# Preston           239
# Brunswick         222
#                  ...
# Sandhurst           1
# Bullengarook        1
# Croydon South       1
# Montrose            1
# Monbulk             1
# Name: Suburb, Length: 314, dtype: int64

# %%
melb_data["Coordinates"].value_counts()
# Out:
# -37.8361, 144.9966      12
# -37.8035, 144.985        8
# -37.8424, 144.9449       6
# -37.8231, 144.9906       5
# -37.8415, 144.9412       5
#                         ..
# -37.7931, 144.9565       1
# -37.7852, 144.9589       1
# -37.7965, 144.9544       1
# -37.7948, 144.9571       1
# -37.81188, 144.88449     1
# Name: Coordinates, Length: 13097, dtype: int64

# %%
melb_data["Type"].value_counts(normalize=True)
# Out:
# h    0.695803
# u    0.222165
# t    0.082032
# Name: Type, dtype: float64

# %%
melb_data['Propertycount'].max()
# Out:
# 21650

# %%
melb_data['Distance'].std()
# Out:
# 5.868724943071711

# %%
abs(melb_data['BuildingArea'].median() - melb_data['BuildingArea'].mean())/melb_data['BuildingArea'].mean()
# Out:
# 0.09764079662364533

# %%
df1= pd.DataFrame([1, 2, 4, 2, 3, 2, 1, 5, 6])

# %%
df1.mode()
# Out:
#    0
# 0  2

# %%
melb_data['Bedroom'].mode()
# Out:
# 0    3
# Name: Bedroom, dtype: int64

# %%
melb_data[melb_data['Bathroom'] == 0].shape[0]
# Out:
# 34

# %%
melb_data[(melb_data['SellerG'] == 'Nelson') & (melb_data['Price'] > 3000000)].shape[0]
# Out:
# 5

# %%
melb_data[melb_data['BuildingArea'] == 0]['Price'].min()
# Out:
# 412500.0

# %%
melb_data[(melb_data['Price']< 1000000) & ((melb_data['Rooms'] > 5) | (melb_data['YearBuilt'] > 2015))].mean()
# Out:
# C:\Users\korek\AppData\Local\Temp\ipykernel_8460\4101020559.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   melb_data[(melb_data['Price']< 1000000) & ((melb_data['Rooms'] > 5) | (melb_data['YearBuilt'] > 2015))].mean()
# index              7914.113636
# Rooms                 4.386364
# Price            769238.636364
# Distance             13.222727
# Postcode           3081.545455
# Bedroom               4.340909
# Bathroom              2.386364
# Car                   1.863636
# Landsize            507.340909
# BuildingArea        161.409091
# YearBuilt          2001.181818
# Lattitude           -37.750565
# Longtitude          144.938987
# Propertycount      6949.863636
# dtype: float64

# %%
melb_data[(melb_data['Type'] == 'h') & (melb_data['Price'] < 3000000)]['Regionname'].mode()
# Out:
# 0    Northern Metropolitan
# Name: Regionname, dtype: object

# %%
melb_df = melb_data.copy()

# %%
melb_df.head()
# Out:
#    index      Suburb           Address  Rooms Type      Price Method SellerG  \
# 0      0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1      1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2      2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3      3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4      4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt  \
# 0  3/12/2016       2.5  ...    1     202.0         126.0       1970
# 1  4/02/2016       2.5  ...    0     156.0          79.0       1900
# 2  4/03/2017       2.5  ...    0     134.0         150.0       1900
# 3  4/03/2017       2.5  ...    1      94.0         126.0       1970
# 4  4/06/2016       2.5  ...    2     120.0         142.0       2014
#
#    CouncilArea  Lattitude  Longtitude             Regionname  Propertycount  \
# ...

# %%
melb_df.drop(labels=['index', 'Coordinates'], axis=1, inplace=True)

# %%
melb_df.head()
# Out:
#        Suburb           Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h  1480000.0      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h  1035000.0      S  Biggin
# 2  Abbotsford      5 Charles St      3    h  1465000.0     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h   850000.0     PI  Biggin
# 4  Abbotsford       55a Park St      4    h  1600000.0     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/12/2016       2.5      3067  ...         1    1     202.0         126.0
# 1  4/02/2016       2.5      3067  ...         1    0     156.0          79.0
# 2  4/03/2017       2.5      3067  ...         2    0     134.0         150.0
# 3  4/03/2017       2.5      3067  ...         2    1      94.0         126.0
# 4  4/06/2016       2.5      3067  ...         1    2     120.0         142.0
#
#    YearBuilt  CouncilArea Lattitude  Longtitude             Regionname  \
# ...

# %%
total_rooms = melb_df['Rooms'] + melb_df['Bathroom'] + melb_df['Bedroom']

# %%
melb_df['MeanRoomsSquare'] = melb_df['BuildingArea'] / total_rooms

# %%
melb_df
# Out:
#               Suburb           Address  Rooms Type      Price Method  \
# 0         Abbotsford      85 Turner St      2    h  1480000.0      S
# 1         Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2         Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3         Abbotsford  40 Federation La      3    h   850000.0     PI
# 4         Abbotsford       55a Park St      4    h  1600000.0     VB
# ...              ...               ...    ...  ...        ...    ...
# 13575  Wheelers Hill      12 Strada Cr      4    h  1245000.0      S
# 13576   Williamstown     77 Merrett Dr      3    h  1031000.0     SP
# 13577   Williamstown       83 Power St      3    h  1170000.0      S
# 13578   Williamstown      96 Verdon St      4    h  2500000.0     PI
# 13579     Yarraville        6 Agnes St      4    h  1285000.0     SP
#
#         SellerG        Date  Distance  Postcode  ...  Car  Landsize  \
# 0        Biggin   3/12/2016       2.5      3067  ...    1     202.0
# ...

# %%
diff_area = melb_df['BuildingArea'] - melb_df['Landsize']
sum_area = melb_df['BuildingArea'] + melb_df['Landsize']
melb_df['AreaRatio'] = diff_area/sum_area

# %%
melb_df['Date'] = pd.to_datetime(melb_df['Date'], dayfirst=True )

# %%
melb_df['Date'].dt.year
# Out:
# 0        2016
# 1        2016
# 2        2017
# 3        2017
# 4        2016
#          ...
# 13575    2017
# 13576    2017
# 13577    2017
# 13578    2017
# 13579    2017
# Name: Date, Length: 13580, dtype: int64

# %%
melb_df['MonthSale'] = melb_df['Date'].dt.month
melb_df['MonthSale'].value_counts(normalize=True)
# Out:
# 5     0.149411
# 7     0.145950
# 9     0.135862
# 6     0.134757
# 8     0.114138
# 11    0.082032
# 4     0.069882
# 3     0.049926
# 12    0.044698
# 10    0.040574
# 2     0.032622
# 1     0.000147
# Name: MonthSale, dtype: float64

# %%
delta_days = melb_df['Date'] - pd.to_datetime('2016-01-01')

# %%
delta_days.dt.days
# Out:
# 0        337
# 1         34
# 2        428
# 3        428
# 4        155
#         ...
# 13575    603
# 13576    603
# 13577    603
# 13578    603
# 13579    603
# Name: Date, Length: 13580, dtype: int64

# %%
melb_df['AgeBuilding'] = melb_df['Date'].dt.year - melb_df['YearBuilt']

# %%
melb_df =melb_df.drop(['YearBuilt'], axis=1)

# %%
melb_df['WeekdaySale'] = melb_df['Date'].dt.day_of_week

# %%
melb_df['WeekdaySale']
# Out:
# 0        5
# 1        3
# 2        5
# 3        5
# 4        5
#         ..
# 13575    5
# 13576    5
# 13577    5
# 13578    5
# 13579    5
# Name: WeekdaySale, Length: 13580, dtype: int64

# %%
weekend_count = melb_df['WeekdaySale'].value_counts()[5] + melb_df['WeekdaySale'].value_counts()[6]

# %%
melb_df['Address'].nunique()
# Out:
# 13378

# %%
def get_street_type(address):
    exclude_list = ['N', 'S', 'W', 'E']
# Метод split() разбивает строку на слова по пробелу.
# В результате получаем список слов в строке и заносим его в переменную address_list.
    address_list = address.split(' ')
# Обрезаем список, оставляя в нём только последний элемент,
# потенциальный подтип улицы, и заносим в переменную street_type.
    street_type = address_list[-1]
# Делаем проверку на то, что полученный подтип является географической пометкой.
# Для этого проверяем его на наличие в списке exclude_list.
    if street_type in exclude_list:
# Если переменная street_type является географической пометкой,
# переопределяем её на второй элемент с конца списка address_list.
        street_type = address_list[-2]
# Возвращаем переменную street_type, в которой хранится подтип улицы.
    return street_type

# %%
street_types = melb_df['Address'].apply(get_street_type)

# %%
#replace = [Av и Avenue, Bvd и Boulevard, Pde и Parade]
street_types = street_types.apply(lambda x: x if x != 'Avenue' else 'Av' )
street_types = street_types.apply(lambda x: x if x != 'Boulevard' else 'Bvd' )
street_types = street_types.apply(lambda x: x if x != 'Parade' else 'Pde' )

# %%
popular_types = street_types.value_counts().nlargest(10).index

# %%
melb_df['StreetType'] = street_types.apply(lambda x: x if x in popular_types else 'other')

# %%
melb_df['StreetType'].nunique()
# Out:
# 11

# %%
melb_df = melb_df.drop(['Address'], axis=1)

# %%
melb_df.head()
# Out:
#        Suburb  Rooms Type      Price Method SellerG       Date  Distance  \
# 0  Abbotsford      2    h  1480000.0      S  Biggin 2016-12-03       2.5
# 1  Abbotsford      2    h  1035000.0      S  Biggin 2016-02-04       2.5
# 2  Abbotsford      3    h  1465000.0     SP  Biggin 2017-03-04       2.5
# 3  Abbotsford      3    h   850000.0     PI  Biggin 2017-03-04       2.5
# 4  Abbotsford      4    h  1600000.0     VB  Nelson 2016-06-04       2.5
#
#    Postcode  Bedroom  ...  Lattitude  Longtitude             Regionname  \
# 0      3067        2  ...   -37.7996    144.9984  Northern Metropolitan
# 1      3067        2  ...   -37.8079    144.9934  Northern Metropolitan
# 2      3067        3  ...   -37.8093    144.9944  Northern Metropolitan
# 3      3067        3  ...   -37.7969    144.9969  Northern Metropolitan
# 4      3067        3  ...   -37.8072    144.9941  Northern Metropolitan
#
#    Propertycount MeanRoomsSquare  AreaRatio  MonthSale AgeBuilding  \
# ...

# %%
def get_weekend(weekday):
    work_days = [0, 1, 2, 3, 4]
    if weekday in work_days:
        weekday = 0
    else:
        weekday = 1
    return weekday

# %%
melb_df['Weekend'] = melb_df['WeekdaySale'].apply(get_weekend)

# %%
melb_df[melb_df['Weekend'] == 1]['Price'].mean()
# Out:
# 1081198.6406956792

# %%
melb_df['Weekend'].value_counts()
# Out:
# 1    12822
# 0      758
# Name: Weekend, dtype: int64

# %%
most_popular_seler = melb_df['SellerG'].value_counts().nlargest(49).index

# %%
melb_df['SellerG'] = melb_df['SellerG'].apply(lambda x: x if x in most_popular_seler else 'other')

# %%
round(melb_df[melb_df['SellerG'] == 'Nelson']['Price'].min() / melb_df[melb_df['SellerG'] == 'other']['Price'].min(), 1)
# Out:
# 1.3

# %%
unique_list = []
for col in melb_df.columns:
    item = (col, melb_df[col].nunique(), melb_df[col].dtype)
    unique_list.append(item)
unique_counts = pd.DataFrame(unique_list, \
    columns=['Column_Name', 'Num_Unique', 'Type']).sort_values(by='Num_Unique', ignore_index=True)
display(unique_counts)
# Out:
#         Column_Name  Num_Unique            Type
# 0           Weekend           2           int64
# 1              Type           3          object
# 2            Method           5          object
# 3       WeekdaySale           5           int64
# 4        Regionname           8          object
# 5          Bathroom           9           int64
# 6             Rooms           9           int64
# 7               Car          11           int64
# 8        StreetType          11          object
# 9           Bedroom          12           int64
# 10        MonthSale          12           int64
# 11      CouncilArea          33          object
# 12          SellerG          50          object
# 13             Date          58  datetime64[ns]
# 14      AgeBuilding         152           int64
# 15         Postcode         198           int64
# 16         Distance         202         float64
# 17    Propertycount         311           int64
# 18           Suburb         314          object
# ...

# %%
col_to_exclude = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car']
max_unique_count = 150
for col in melb_df.columns:
    if melb_df[col].nunique() < max_unique_count and col not in col_to_exclude:
        melb_df[col] = melb_df[col].astype('category')
display(melb_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  object
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
#  15  Lattitude        13580 non-null  float64
# ...

# %%
melb_df['Regionname'].cat.categories
# Out:
# Index(['Eastern Metropolitan', 'Eastern Victoria', 'Northern Metropolitan',
#        'Northern Victoria', 'South-Eastern Metropolitan',
#        'Southern Metropolitan', 'Western Metropolitan', 'Western Victoria'],
#       dtype='object')

# %%
melb_df['Type'] = melb_df['Type'].cat.rename_categories({'u':'unit', 't':'townhouse', 'h':'house'})
display(melb_df['Type'])
# Out:
# 0        house
# 1        house
# 2        house
# 3        house
# 4        house
#          ...
# 13575    house
# 13576    house
# 13577    house
# 13578    house
# 13579    house
# Name: Type, Length: 13580, dtype: category
# Categories (3, object): ['house', 'townhouse', 'unit']

# %%
melb_df['Type'] = melb_df['Type'].cat.add_categories('flat')
new_houses_types = pd.Series(['unit', 'house', 'flat', 'flat', 'house'])
new_houses_types = new_houses_types.astype(melb_df['Type'].dtype)

# %%
display(new_houses_types)
# Out:
# 0     unit
# 1    house
# 2     flat
# 3     flat
# 4    house
# dtype: category
# Categories (4, object): ['house', 'townhouse', 'unit', 'flat']

# %%
melb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  object
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
#  15  Lattitude        13580 non-null  float64
# ...

# %%
max_suburb = melb_df['Suburb'].value_counts().nlargest(119)
melb_df['Suburb'] = melb_df['Suburb'].apply(lambda x: x if x in max_suburb else 'other')

# %%
melb_df['Suburb'] = melb_df['Suburb'].astype('category')

# %%
melb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  category
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
#  15  Lattitude        13580 non-null  float64
# ...

# %%
melb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  category
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
#  15  Lattitude        13580 non-null  float64
# ...

# %%
melb_df['Date'].dt.quarter.value_counts()
# Out:
# 3    5377
# 2    4808
# 4    2272
# 1    1123
# Name: Date, dtype: int64

# %%
exclusion = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car']
category = list(unique_counts[unique_counts['Num_Unique'] < 150]['Column_Name'].apply(lambda x: x if x not in exclusion else None).dropna())
melb_df[category] = melb_df[category].astype('category')
melb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Suburb           13580 non-null  category
#  1   Rooms            13580 non-null  int64
#  2   Type             13580 non-null  category
#  3   Price            13580 non-null  float64
#  4   Method           13580 non-null  category
#  5   SellerG          13580 non-null  category
#  6   Date             13580 non-null  datetime64[ns]
#  7   Distance         13580 non-null  float64
#  8   Postcode         13580 non-null  int64
#  9   Bedroom          13580 non-null  int64
#  10  Bathroom         13580 non-null  int64
#  11  Car              13580 non-null  int64
#  12  Landsize         13580 non-null  float64
#  13  BuildingArea     13580 non-null  float64
#  14  CouncilArea      12211 non-null  category
#  15  Lattitude        13580 non-null  float64
# ...

# %%
mask1 = melb_df['AreaRatio'] < -0.8
mask2 = melb_df['Type'] == 'townhouse'
mask3 = melb_df['SellerG'] == 'McGrath'

# %%
melb_df[mask1 & mask2 & mask3].sort_values( by = ['Date', 'AreaRatio'], ascending=[True, False], ignore_index=True,).loc[:, ['Date', 'AreaRatio']]
# Out:
#         Date  AreaRatio
# 0 2016-07-26  -0.974922
# 1 2016-09-24  -0.971831
# 2 2016-11-12  -0.945946
# 3 2016-11-27  -0.953608
# 4 2017-04-08  -0.947368
# 5 2017-04-08  -0.970874

# %%
melb_df.sort_values(by=['AreaRatio'], ascending=False, ignore_index=True)['BuildingArea'].iloc[1558]
# Out:
# 126.0

# %%
table1 = melb_df[(melb_df['Rooms'] > 2) & (melb_df['Type'] == 'townhouse')]

# %%
table1.sort_values(by=['Rooms', 'MeanRoomsSquare'], ascending=[True, False], ignore_index=True )['Price'].iloc[18]
# Out:
# 1300000.0

# %%
melb_df.groupby('MonthSale')['Price'].agg(['count', 'mean', 'max']).sort_values(by='count', ascending=False)
# Out:
#            count          mean        max
# MonthSale
# 5           2029  1.095086e+06  8000000.0
# 7           1982  8.995594e+05  9000000.0
# 9           1845  1.133612e+06  6400000.0
# 6           1830  1.076351e+06  7650000.0
# 8           1550  1.140499e+06  6500000.0
# 11          1114  1.117513e+06  5700000.0
# 4            949  1.018167e+06  5800000.0
# 3            678  1.141256e+06  5500000.0
# 12           607  1.170918e+06  5500000.0
# 10           551  1.065341e+06  6250000.0
# 2            443  1.104372e+06  4735000.0
# 1              2  1.009000e+06  1205000.0

# %%
melb_df.groupby('Regionname')['SellerG'].agg(['nunique', set])
# Out:
#                             nunique  \
# Regionname
# Eastern Metropolitan             26
# Eastern Victoria                 11
# Northern Metropolitan            40
# Northern Victoria                11
# South-Eastern Metropolitan       25
# Southern Metropolitan            38
# Western Metropolitan             34
# Western Victoria                  6
#
#                                                                           set
# Regionname
# Eastern Metropolitan        {Stockdale, Gary, Noel, Woodards, other, McGra...
# Eastern Victoria            {O'Brien, C21, Fletchers, Eview, other, McGrat...
# Northern Metropolitan       {Stockdale, Alexkarbon, YPA, Nick, Woodards, o...
# Northern Victoria           {YPA, McDonald, Raine, Buckingham, other, McGr...
# South-Eastern Metropolitan  {Stockdale, Gary, Noel, Woodards, other, McGra...
# Southern Metropolitan       {Stockdale, Gary, Nick, Noel, Woodards, other,...
# ...

# %%
melb_df.groupby('Rooms')['Price'].agg(['mean']).sort_values(by='mean', ascending=False)
# Out:
#                mean
# Rooms
# 7      1.920700e+06
# 5      1.870260e+06
# 6      1.849366e+06
# 8      1.602750e+06
# 4      1.445282e+06
# 3      1.076081e+06
# 10     9.000000e+05
# 2      7.750812e+05
# 1      4.338245e+05

# %%
melb_df.groupby('Regionname')['Lattitude'].agg(['std']).sort_values(by='std', ascending=True)
# Out:
#                                  std
# Regionname
# Western Victoria            0.011579
# Southern Metropolitan       0.043080
# Eastern Metropolitan        0.047890
# Northern Metropolitan       0.049639
# Western Metropolitan        0.051251
# South-Eastern Metropolitan  0.073411
# Northern Victoria           0.084455
# Eastern Victoria            0.147067

# %%
month_list = [5,6,7,8,9]
table_2 = pd.DataFrame(melb_df['Date'].dt.year)
table_2['month'] = melb_df['Date'].dt.month
table_2['SallerG'] = melb_df['SellerG']
table_2['Price'] = melb_df['Price']

# %%
table_2['month'] = table_2['month'].apply(lambda x: x if x in month_list else None)

# %%
table_2 = table_2.dropna()
table_2[table_2['Date'] == 2017].groupby('SallerG')['Price'].agg('sum').sort_values(ascending=True)
# Out:
# SallerG
# LITTLE             4509000.0
# Burnham            5968000.0
# Moonee             8045000.0
# Thomson           10974000.0
# Bells             12531000.0
# Alexkarbon        12992000.0
# Rendina           20072276.0
# Cayzer            20377000.0
# McDonald          20937500.0
# Nick              21955000.0
# Douglas           22367000.0
# Buckingham        23802100.0
# Eview             25524500.0
# Collins           25675000.0
# C21               29958000.0
# Purplebricks      30218001.0
# Philip            31981800.0
# Love              32600500.0
# Williams          33080000.0
# Chisholm          33153250.0
# Village           34788000.0
# RW                41045000.0
# HAR               42748000.0
# Raine             43535700.0
# O'Brien           46294508.0
# Gary              50329300.0
# Stockdale         57637300.0
# Sweeney           57718250.0
# Miles             57953000.0
# Jas               71805100.0
# YPA               75486850.0
# ...

# %%
date1 = pd.to_datetime('2017-05-01')
date2 = pd.to_datetime('2017-09-01')
mask = (date1 <= melb_df['Date']) & (melb_df['Date']<= date2)
melb_df[mask].groupby('SellerG')['Price'].sum().sort_values(ascending=True)
# Out:
# SellerG
# LITTLE             4509000.0
# Burnham            5968000.0
# Moonee             8045000.0
# Bells             10311000.0
# Thomson           10974000.0
# Alexkarbon        11387000.0
# Cayzer            15000000.0
# Nick              16665000.0
# Douglas           17586000.0
# Rendina           18242276.0
# Eview             19036500.0
# McDonald          19727500.0
# Buckingham        20597100.0
# Collins           22730000.0
# C21               23222500.0
# Love              23357500.0
# Philip            24895300.0
# Williams          24996000.0
# Purplebricks      26826501.0
# HAR               28690000.0
# Chisholm          29663250.0
# RW                31751500.0
# Village           32533000.0
# Raine             34343700.0
# O'Brien           36835508.0
# Stockdale         42174800.0
# Gary              46945300.0
# Sweeney           47091250.0
# Miles             51962000.0
# YPA               59917350.0
# Jas               61651100.0
# ...

# %%
melb_df.groupby('Rooms')[['Price', 'BuildingArea']].median()
# Out:
#            Price  BuildingArea
# Rooms
# 1       385000.0         107.0
# 2       690000.0         126.0
# 3       950000.0         126.0
# 4      1285000.0         142.0
# 5      1660000.0         176.0
# 6      1800000.0         126.0
# 7      1496000.0         216.5
# 8      1515000.0         126.0
# 10      900000.0         126.0

# %%
melb_df.groupby(['Rooms', 'Type'])['Price'].mean()
# Out:
# Rooms  Type
# 1      house        8.668655e+05
#        townhouse    5.927045e+05
#        unit         3.899289e+05
#        flat                  NaN
# 2      house        1.017238e+06
#        townhouse    7.101585e+05
#        unit         6.104905e+05
#        flat                  NaN
# 3      house        1.109233e+06
#        townhouse    9.847087e+05
#        unit         8.505963e+05
#        flat                  NaN
# 4      house        1.462283e+06
#        townhouse    1.217092e+06
#        unit         1.037476e+06
#        flat                  NaN
# 5      house        1.877327e+06
#        townhouse    1.035000e+06
#        unit                  NaN
#        flat                  NaN
# 6      house        1.869508e+06
#        townhouse             NaN
#        unit         5.200000e+05
#        flat                  NaN
# 7      house        1.920700e+06
#        townhouse             NaN
#        unit                  NaN
#        flat                  NaN
# ...

# %%
melb_df.groupby(['Rooms', 'Type'])['Price'].mean().unstack()
# Out:
# Type          house     townhouse          unit  flat
# Rooms
# 1      8.668655e+05  5.927045e+05  3.899289e+05   NaN
# 2      1.017238e+06  7.101585e+05  6.104905e+05   NaN
# 3      1.109233e+06  9.847087e+05  8.505963e+05   NaN
# 4      1.462283e+06  1.217092e+06  1.037476e+06   NaN
# 5      1.877327e+06  1.035000e+06           NaN   NaN
# 6      1.869508e+06           NaN  5.200000e+05   NaN
# 7      1.920700e+06           NaN           NaN   NaN
# 8      1.510286e+06           NaN  2.250000e+06   NaN
# 10     9.000000e+05           NaN           NaN   NaN

# %%
melb_df.pivot_table(values='Price', index='Rooms', columns='Type', fill_value=0).round()
# Out:
# Type       house  townhouse       unit
# Rooms
# 1       866866.0   592705.0   389929.0
# 2      1017238.0   710158.0   610491.0
# 3      1109233.0   984709.0   850596.0
# 4      1462283.0  1217092.0  1037476.0
# 5      1877327.0  1035000.0        0.0
# 6      1869508.0        0.0   520000.0
# 7      1920700.0        0.0        0.0
# 8      1510286.0        0.0  2250000.0
# 10      900000.0        0.0        0.0

# %%
melb_df.pivot_table(values='Price', index='Regionname', columns='Weekend', aggfunc='count')
# Out:
# Weekend                       0     1
# Regionname
# Eastern Metropolitan         52  1419
# Eastern Victoria              0    53
# Northern Metropolitan       246  3644
# Northern Victoria             0    41
# South-Eastern Metropolitan    2   448
# Southern Metropolitan       275  4420
# Western Metropolitan        183  2765
# Western Victoria              0    32

# %%
melb_df['Weekend'].value_counts()
# Out:
# 1    12822
# 0      758
# Name: Weekend, dtype: int64

# %%
melb_df.pivot_table(
    values='Landsize',
    index='Regionname',
    columns='Type',
    aggfunc=['median', 'mean'],
    fill_value=0
)
# Out:
#                            median                        mean              \
# Type                        house townhouse unit        house   townhouse
# Regionname
# Eastern Metropolitan        674.0     233.5  203   717.422847  269.440678
# Eastern Victoria            843.0       0.0  230  3108.960000    0.000000
# Northern Metropolitan       459.5     134.0    0   619.249092  317.325733
# Northern Victoria           724.0       0.0    0  3355.463415    0.000000
# South-Eastern Metropolitan  630.5     240.0  199   664.306701  212.160000
# Southern Metropolitan       586.0     246.0    0   569.643881  278.858824
# Western Metropolitan        531.0     198.0   62   507.883406  244.560669
# Western Victoria            599.5       0.0    0   655.500000    0.000000
#
#
# Type                              unit
# Regionname
# Eastern Metropolitan        330.444444
# Eastern Victoria            295.333333
# Northern Metropolitan       495.026538
# Northern Victoria             0.000000
# ...

# %%
melb_df.pivot_table(
    values='Price',
    index=['Method','Type'],
    columns='Regionname',
    aggfunc='median',
    fill_value=0
)
# Out:
# Regionname        Eastern Metropolitan  Eastern Victoria  \
# Method Type
# PI     house                   1244000            780000
#        townhouse                760000                 0
#        unit                     650000                 0
# S      house                   1127000            675000
#        townhouse                828000                 0
#        unit                     645750            492000
# SA     house                    932500            950000
#        townhouse                807500                 0
#        unit                          0                 0
# SP     house                   1050000            672500
#        townhouse                910000                 0
#        unit                     515000            400000
# VB     house                   1100000            712500
#        townhouse                892500                 0
#        unit                     500000                 0
#
# ...

# %%
pivot = melb_df.pivot_table(
    values='Landsize',
    index='Regionname',
    columns='Type',
    aggfunc=['median', 'mean'],
    fill_value=0
)

# %%
pivot.columns
# Out:
# MultiIndex([('median',     'house'),
#             ('median', 'townhouse'),
#             ('median',      'unit'),
#             (  'mean',     'house'),
#             (  'mean', 'townhouse'),
#             (  'mean',      'unit')],
#            names=[None, 'Type'])

# %%
pivot
# Out:
#                            median                        mean              \
# Type                        house townhouse unit        house   townhouse
# Regionname
# Eastern Metropolitan        674.0     233.5  203   717.422847  269.440678
# Eastern Victoria            843.0       0.0  230  3108.960000    0.000000
# Northern Metropolitan       459.5     134.0    0   619.249092  317.325733
# Northern Victoria           724.0       0.0    0  3355.463415    0.000000
# South-Eastern Metropolitan  630.5     240.0  199   664.306701  212.160000
# Southern Metropolitan       586.0     246.0    0   569.643881  278.858824
# Western Metropolitan        531.0     198.0   62   507.883406  244.560669
# Western Victoria            599.5       0.0    0   655.500000    0.000000
#
#
# Type                              unit
# Regionname
# Eastern Metropolitan        330.444444
# Eastern Victoria            295.333333
# Northern Metropolitan       495.026538
# Northern Victoria             0.000000
# ...

# %%
pivot['median']['unit']
# Out:
# Regionname
# Eastern Metropolitan          203
# Eastern Victoria              230
# Northern Metropolitan           0
# Northern Victoria               0
# South-Eastern Metropolitan    199
# Southern Metropolitan           0
# Western Metropolitan           62
# Western Victoria                0
# Name: unit, dtype: int64

# %%
mask = pivot['mean']['house'] < pivot['median']['house']
filtered_pivot = pivot[mask]
display(filtered_pivot)
# Out:
#                       median                       mean              \
# Type                   house townhouse unit       house   townhouse
# Regionname
# Southern Metropolitan  586.0     246.0    0  569.643881  278.858824
# Western Metropolitan   531.0     198.0   62  507.883406  244.560669
#
#
# Type                         unit
# Regionname
# Southern Metropolitan  466.380245
# Western Metropolitan   557.637232

# %%
print(list(filtered_pivot.index))
# Out:
# ['Southern Metropolitan', 'Western Metropolitan']

# %%
melb_df.pivot_table(values='BuildingArea', index='Rooms', columns='Type', aggfunc='median').sort_values(by=['house'], ascending=False)
# Out:
# Type   house  townhouse   unit
# Rooms
# 7      216.5        NaN    NaN
# 5      177.0      152.0    NaN
# 4      141.0      159.5  126.0
# 1      126.0       88.0   69.5
# 2      126.0      114.0  110.0
# 3      126.0      126.0  126.0
# 6      126.0        NaN  171.0
# 8      126.0        NaN  126.0
# 10     126.0        NaN    NaN

# %%
melb_df.pivot_table(values='Price', index='SellerG', columns='Type', aggfunc='median').sort_values(by='unit', ascending=False)
# Out:
# Type               house  townhouse      unit
# SellerG
# Nick           2025000.0   780000.0  900000.0
# Marshall       1975000.0  1408500.0  715000.0
# Cayzer         1505000.0  1450000.0  707500.0
# Kay            2220000.0  1365000.0  695000.0
# Noel           1400500.0   990000.0  693250.0
# Buxton         1323750.0  1030000.0  670000.0
# Fletchers      1390000.0  1238000.0  653000.0
# Chisholm       1520000.0   950000.0  640000.0
# Philip         1035000.0   701000.0  636000.0
# RT             1640000.0  1400000.0  630000.0
# C21             836500.0   768750.0  625500.0
# RW              870000.0   630500.0  625500.0
# Moonee          806000.0   715000.0  622000.0
# O'Brien         737504.0   430000.0  618500.0
# Hodges         1500000.0  1105000.0  605500.0
# Eview           760000.0   597500.0  602000.0
# Woodards       1261000.0   865500.0  600000.0
# Collins        1566500.0   930000.0  592000.0
# Jellis         1505000.0  1052000.0  591750.0
# ...
